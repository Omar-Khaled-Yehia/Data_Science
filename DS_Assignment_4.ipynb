# %%
import numpy as np
import pandas as pd

# %%
# 1. Write a Pandas program to create and display a one-dimensional array-like object containing an array of data using Pandas module.
arr=pd.Series(["a","b","c","d","e"])
arr
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
# 2. Write a Pandas program to convert a Panda module Series to Python list and it's type.
arr.to_list()
print(type(arr))
arr=list(arr)
print(type(arr))  # to_list function just returns a list and does not convert its type so I've done it both ways.
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>

# %%
# 3. Write a Pandas program to compare the elements of the two Pandas Series.
a1=pd.Series([1,2,3,4,5])
a2=pd.Series([1,2,3,4,6])
a1.equals(a2)
# Out:
# False

# %%
# 4. Write a Pandas program to change the data type of given a column or a Series.
print(a1)
a1.astype(float)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
# 5. Write a Pandas program to get the powers of an array values element-wise.
a1=pd.Series([1,2,3,4,5])
a2=pd.Series([0,1,2,1,2])
a1=a1.apply(lambda x: x**a2)
a1
# Out:
#    0  1   2  3   4
# 0  1  1   1  1   1
# 1  1  2   4  2   4
# 2  1  3   9  3   9
# 3  1  4  16  4  16
# 4  1  5  25  5  25

# %%
# Note: First array elements raised to powers from second array Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
df=pd.DataFrame(data= {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})
df
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
# 6. Write a Pandas program to get the first 3 rows of a given DataFrame.
df_2=pd.DataFrame(data = {'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
                          'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael','Matthew', 'Laura', 'Kevin', 'Jonas'],
                          'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],
                          'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19]}
                  ,index= ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
df_2.head(3)
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5

# %%
# 7. Write a Pandas program to display the default index and set a column as an Index in a given dataframe.
test= {'0':[0,1,2,3,4,5],'1':['Streat1','Streat2','Streat3','Streat4','Streat5','Streat6'],'2':['S001','S002','S003','S004','S005','S006'],'3':['V','V','VI','VI','V','VI'],'4':['Alberto','Gino', 'Ryan','Eesha', 'Gino','David'],
       '5':['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],'6':[35,32,33,30,31,32]}
pd1=pd.DataFrame(test)
pd1 = pd1.set_index('0')
pd1
# Out:
#          1     2   3        4           5   6
# 0
# 0  Streat1  S001   V  Alberto  15/05/2002  35
# 1  Streat2  S002   V     Gino  17/05/2002  32
# 2  Streat3  S003  VI     Ryan  16/02/1999  33
# 3  Streat4  S004  VI    Eesha  25/09/1998  30
# 4  Streat5  S005   V     Gino  11/05/2002  31
# 5  Streat6  S006  VI    David  15/09/1997  32

# %%
# 8. Write a Pandas program to display the default index and set a column as an Index in a given dataframe and then reset the index
pd1
# Out:
#          1     2   3        4           5   6
# 0
# 0  Streat1  S001   V  Alberto  15/05/2002  35
# 1  Streat2  S002   V     Gino  17/05/2002  32
# 2  Streat3  S003  VI     Ryan  16/02/1999  33
# 3  Streat4  S004  VI    Eesha  25/09/1998  30
# 4  Streat5  S005   V     Gino  11/05/2002  31
# 5  Streat6  S006  VI    David  15/09/1997  32

# %%
pd1=pd1.reset_index()
pd1
# Out:
#    0        1     2   3        4           5   6
# 0  0  Streat1  S001   V  Alberto  15/05/2002  35
# 1  1  Streat2  S002   V     Gino  17/05/2002  32
# 2  2  Streat3  S003  VI     Ryan  16/02/1999  33
# 3  3  Streat4  S004  VI    Eesha  25/09/1998  30
# 4  4  Streat5  S005   V     Gino  11/05/2002  31
# 5  5  Streat6  S006  VI    David  15/09/1997  32

# %%
# 9. Write a Pandas program to create a dataframe indexing by date and time.
pd1=pd1.set_index('5')
pd1
# Out:
#             0        1     2   3        4   6
# 5
# 15/05/2002  0  Streat1  S001   V  Alberto  35
# 17/05/2002  1  Streat2  S002   V     Gino  32
# 16/02/1999  2  Streat3  S003  VI     Ryan  33
# 25/09/1998  3  Streat4  S004  VI    Eesha  30
# 11/05/2002  4  Streat5  S005   V     Gino  31
# 15/09/1997  5  Streat6  S006  VI    David  32

# %%
# 10. Write a Pandas program to create a dataframe and set a title or name of the index column
pd1=pd1.rename_axis('aaaaa',axis='index')
pd1
# Out:
#             0        1     2   3        4   6
# aaaaa
# 15/05/2002  0  Streat1  S001   V  Alberto  35
# 17/05/2002  1  Streat2  S002   V     Gino  32
# 16/02/1999  2  Streat3  S003  VI     Ryan  33
# 25/09/1998  3  Streat4  S004  VI    Eesha  30
# 11/05/2002  4  Streat5  S005   V     Gino  31
# 15/09/1997  5  Streat6  S006  VI    David  32

# %%
# 11. Write a Pandas program to select a specific row of given series/dataframe by integer index.

pd1[pd1['6']==30]
# Out:
#             0        1     2   3      4   6
# aaaaa
# 25/09/1998  3  Streat4  S004  VI  Eesha  30
